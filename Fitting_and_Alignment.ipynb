# %% [markdown]
# ## Question 1

# %%
# !pip install scikit-image
# !pip install tikzplotlib
# Out:
# Requirement already satisfied: scikit-image in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (0.24.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from scikit-image) (2.1.2)
# Requirement already satisfied: scipy>=1.9 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from scikit-image) (1.14.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from scikit-image) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from scikit-image) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from scikit-image) (2024.9.20)
# Requirement already satisfied: packaging>=21 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from scikit-image) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from scikit-image) (0.4)
# Requirement already satisfied: tikzplotlib in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (0.10.1)
# Requirement already satisfied: matplotlib>=1.4.0 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from tikzplotlib) (3.9.2)
# Requirement already satisfied: numpy in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from tikzplotlib) (2.1.2)
# Requirement already satisfied: Pillow in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from tikzplotlib) (11.0.0)
# Requirement already satisfied: webcolors in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from tikzplotlib) (24.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from matplotlib>=1.4.0->tikzplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from matplotlib>=1.4.0->tikzplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from matplotlib>=1.4.0->tikzplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from matplotlib>=1.4.0->tikzplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from matplotlib>=1.4.0->tikzplotlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from matplotlib>=1.4.0->tikzplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from matplotlib>=1.4.0->tikzplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\downloads\jayathissa\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->tikzplotlib) (1.16.0)

# %%
import cv2 as cv
import numpy as np
from skimage.feature import blob_log
from math import sqrt
import matplotlib.pyplot as plt

# Load image
im = cv.imread('the_berry_farms_sunflower_field.jpeg', cv.IMREAD_REDUCED_COLOR_4)
assert im is not None
# Convert to grayscale
gray_im = cv.cvtColor(im, cv.COLOR_BGR2GRAY)

# Create a three-channel grayscale image
gray_three_channel = cv.merge([gray_im, gray_im, gray_im])

# Apply Gaussian blur to reduce noise
blurred = cv.GaussianBlur(gray_im, (9, 9), 0.1)

# Define parameters for blob detection
min_sigma = 3
max_sigma = 30
threshold = .1

# Detect blobs using Laplacian of Gaussians
blobs = blob_log(blurred, min_sigma=min_sigma,max_sigma=max_sigma, threshold=threshold)
blobs[:, 2] = blobs[:, 2] * sqrt(2)

max_radius_index = np.argmax(blobs[:, 2])
largest_circle_params = blobs[max_radius_index]
y, x, r = largest_circle_params
print(f"Radius (r): {r}")
print(f"Center (x, y): ({x}, {y})")

# Draw circles on the original grayscale image
for blob in blobs:
    y, x, r = blob  # Blob format is (y, x, r)
    cv.circle(gray_three_channel, (int(x), int(y)), int(r), (255,0,255), 2)

# Display the result
plt.imshow(gray_three_channel)
plt.title('Detected Circles')
plt.axis('off')
plt.show()
# Out:
# Radius (r): 42.42640687119285
# Center (x, y): (234.0, 0.0)

# %% [markdown]
# ## Question 2

# %%
from scipy.optimize import minimize
from scipy import linalg
import matplotlib.pyplot as plt
import numpy as np
#import tikzplotlib

# Set random seed
np.random.seed(0)

# Constants
N = 100
half_n = N // 2

# Parameters
r = 10
x0_gt, y0_gt = 2, 3
s = r / 16
t = np.random.uniform(0, 2 * np.pi, half_n)
n = s * np.random.randn(half_n)
x, y = x0_gt + (r + n) * np.cos(t), y0_gt + (r + n) * np.sin(t)
X_circ = np.hstack((x.reshape(half_n, 1), y.reshape(half_n, 1)))

s, m, b = 1, -1, 2
x = np.linspace(-12, 12, half_n)
y = m * x + b + s * np.random.randn(half_n)
X_line = np.hstack((x.reshape(half_n, 1), y.reshape(half_n, 1)))

X = np.vstack((X_circ, X_line))

# Plotting
def plot_all(separate = True):
    fig, ax = plt.subplots(1, 1, figsize=(8, 8))

    if separate:
        ax.scatter(X_line[:, 0], X_line[:, 1], label='Line')
        ax.scatter(X_circ[:, 0], X_circ[:, 1], label='Circle')
    else:
        ax.scatter(X[:, 0], X[:, 1], label='Point Set')

    circle_gt = plt.Circle((x0_gt, y0_gt), r, color='g', fill=False, label='Ground truth circle')
    ax.add_patch(circle_gt)
    ax.plot(x0_gt, y0_gt, '+', color='g')

    x_min, x_max = ax.get_xlim()
    x_ = np.array([x_min, x_max])
    y_ = m * x_ + b
    plt.plot(x_, y_, color='m', label='Ground truth line')

    plt.legend()
    return ax

plot_all()
# Out:
# <Axes: >

# %%
def dist(p1, p2):
    (x1, y1), (x2, y2) = p1, p2
    return ((x1 - x2)**2 + (y1 - y2)**2)**0.5

def line_eq(p1, p2):
    (x1, y1), (x2, y2) = p1, p2
    a = (y2 - y1)
    b = -(x2 - x1)
    d = a*x1 + b*y1
    assert abs(a*x2 + b*y2 - d) < 1e-8

    # Apply constraint
    norm = (a**2 + b**2)**0.5
    a, b, d = a/norm, b/norm, d/norm
    return a, b, d

def circle_eq(p1, p2, p3):
    (x1, y1), (x2, y2), (x3, y3) = p1, p2, p3

    # circumcenter of circle is equidistant to all points
    mx1, my1 = (x1 + x2)/2, (y1 + y2)/2
    mx2, my2 = (x1 + x3)/2, (y1 + y3)/2

    s1 = -(x2 - x1)/(y2 - y1)
    s2 = -(x3 - x1)/(y3 - y1)

    c1 = my1 - s1 * mx1
    c2 = my2 - s2 * mx2

    cx = (c2 - c1)/(s1 - s2)
    cy = s1 * cx + c1
    assert abs(s2 * cx + c2 - cy) < 1e-8

    r = dist((cx, cy), p1)
    assert abs(dist((cx, cy), p2) - dist((cx, cy), p1)) < 1e-8
    return cx, cy, r

# %%
# Squared error calculation for line and circle
def tls_error_line(params, *args):
    # Error of points denoted by indices, params is the one that should be optimized
    a, b, d = params
    indices, X = args
    error = np.sum((a * X[indices, 0] + b * X[indices, 1] - d)**2)
    return error

def tls_error_circle(params, *args):
    cx, cy, r = params
    indices, X = args
    error = np.sum((dist((cx, cy), (X[indices, 0], X[indices, 1])) - r)**2)
    return error

# %%
def consensus_line(params, thres, X):   # Whether each point is an inlier
    a, b, d = params
    errors = np.abs(a * X[:, 0] + b * X[:, 1] - d)
    return np.where(errors < thres)

def consensus_circle(params, thres, X):   # Whether each point is an inlier
    cx, cy, r = params
    errors = np.abs(dist((cx, cy), (X[:, 0], X[:, 1])) - r) # radial error
    return np.where(errors < thres)

def constraint(params): # Should be equal to zero
    a, b, d = params
    return (a**2 + b**2)**0.5 - 1

constraint_dict = {'type':'eq', 'fun':constraint}

def least_squares_line_fit(indices, initial, X):  # line fitting with scipy minimize
    res = minimize(fun=tls_error_line, x0=initial, args=(indices, X), constraints=constraint_dict, tol=1e-6)
    print(res.x, res.fun)
    return res

def least_squares_circ_fit(indices, initial, X):
    res = minimize(fun=tls_error_circle, x0=initial, args=(indices, X), tol=1e-6)
    print(res.x, res.fun)
    return res

# %%
# Fitting the line

iters = 100
min_points = 2
N = X.shape[0]
np.random.seed(14)

thres = 1.   # Error threshold for selecting inliers
d = 0.4 * N # Minimum inlier count for a good fit

best_model_line = None
best_fitted_line = None
best_error = np.inf
best_line_inliers = None
best_line_sample_points = None

for i in range(iters):
    indices = np.random.choice(np.arange(0, N), size=min_points, replace=False)
    params = line_eq(X[indices[0]], X[indices[1]])
    inliers = consensus_line(params, thres, X)[0]
    print(f'Iteration {i}: No. of inliers = {len(inliers)}')

    if len(inliers) >= d:   # compute again
        res = least_squares_line_fit(inliers, params, X)
        if res.fun < best_error:
# Iteration 69: No. of inliers = 40
# [0.74044163 0.67212067 1.85905177] 9.213091010643502
# Iteration 70: No. of inliers = 6
# Iteration 71: No. of inliers = 8
# Iteration 72: No. of inliers = 7
# Iteration 73: No. of inliers = 13
# Iteration 74: No. of inliers = 17
# Iteration 75: No. of inliers = 13
# Iteration 76: No. of inliers = 8
# Iteration 77: No. of inliers = 12
# Iteration 78: No. of inliers = 38
# Iteration 79: No. of inliers = 11
# Iteration 80: No. of inliers = 20
# Iteration 81: No. of inliers = 29
# Iteration 82: No. of inliers = 8
# Iteration 83: No. of inliers = 5
# Iteration 84: No. of inliers = 39
# Iteration 85: No. of inliers = 22
# Iteration 86: No. of inliers = 41
# [-0.69508986 -0.71892288 -1.31504651] 11.644783105363128
# Iteration 87: No. of inliers = 13
# Iteration 88: No. of inliers = 19
# Iteration 89: No. of inliers = 10
# Iteration 90: No. of inliers = 6
# Iteration 91: No. of inliers = 21
# Iteration 92: No. of inliers = 7
# Iteration 93: No. of inliers = 11
# Iteration 94: No. of inliers = 13
# Iteration 95: No. of inliers = 42
# [-0.70898672 -0.70522183 -1.48866098] 10.131515891053247
# Iteration 96: No. of inliers = 7
# Iteration 97: No. of inliers = 17
# Iteration 98: No. of inliers = 7
# Iteration 99: No. of inliers = 17
# Best line = [0.71205467 0.70212402 1.53281698], No. of inliers = 52, best_error = 8.09865025050975

# %%
# fitting the circle

remaining_points = np.array([i for i in range(N) if i not in line_inliers])
X_rem = X[remaining_points]

iters = 100
min_points = 3  # We need 3 points to estimate a circle

thres = 1.2   # Error threshold for selecting inliers
d = 0.4 * N # Minimum inlier count for a good fit

best_model_circle = None
best_fitted_circle = None
best_error = np.inf
best_circ_inliers = None
best_circ_sample_points = None

for i in range(iters):
    indices = np.random.choice(np.arange(len(X_rem)), size=min_points, replace=False)
    params = circle_eq(*X_rem[indices])
    inliers = consensus_circle(params, thres, X_rem)[0]
    print(f'Iteration {i}: No. of inliers = {len(inliers)}')

    if len(inliers) >= d:   # compute again
        res = least_squares_circ_fit(inliers, params, X_rem)
        if res.fun < best_error:
            best_error = res.fun
            best_model_circle = params
            best_fitted_circle = res.x
            best_circ_inliers = inliers
            best_circ_sample_points = indices

circ_inliers = consensus_circle(best_fitted_circle, thres, X_rem)[0]

print(f'Best circle = {best_fitted_circle}, No. of inliers = {len(circ_inliers)}, best_error = {best_error}')
# Out:
# Iteration 0: No. of inliers = 10
# Iteration 1: No. of inliers = 12
# Iteration 2: No. of inliers = 10
# Iteration 3: No. of inliers = 41
# [1.8828232  3.18299016 9.81978826] 8.709305494445344
# Iteration 4: No. of inliers = 34
# Iteration 5: No. of inliers = 5
# Iteration 6: No. of inliers = 25
# Iteration 7: No. of inliers = 21
# Iteration 8: No. of inliers = 30
# Iteration 9: No. of inliers = 41
# [1.69665199 3.00402845 9.92790141] 9.203751651287867
# Iteration 10: No. of inliers = 37
# Iteration 11: No. of inliers = 17
# Iteration 12: No. of inliers = 25
# Iteration 13: No. of inliers = 35
# Iteration 81: No. of inliers = 43
# [1.82394243 2.97629434 9.82797582] 10.582338154521
# Iteration 82: No. of inliers = 23
# Iteration 83: No. of inliers = 24
# Iteration 84: No. of inliers = 38
# Iteration 85: No. of inliers = 33
# Iteration 86: No. of inliers = 39
# Iteration 87: No. of inliers = 8
# Iteration 88: No. of inliers = 24
# Iteration 89: No. of inliers = 42
# [1.81875531 3.14509642 9.87704621] 9.250674952441742
# Iteration 90: No. of inliers = 35
# Iteration 91: No. of inliers = 7
# Iteration 92: No. of inliers = 30
# Iteration 93: No. of inliers = 33
# Iteration 94: No. of inliers = 7
# Iteration 95: No. of inliers = 19
# Iteration 96: No. of inliers = 28
# Iteration 97: No. of inliers = 28
# Iteration 98: No. of inliers = 10
# Iteration 99: No. of inliers = 35
# Best circle = [1.77512491 3.14178349 9.90131913], No. of inliers = 45, best_error = 8.033794949425614

# %%
ax = plot_all(False)

x_min, x_max = ax.get_xlim()
x_ = np.array([x_min, x_max])
A, B, D = best_fitted_line
indices = line_inliers

y_ = (D - A*x_) / B
plt.plot(x_, y_, color='r', label='RANSAC line')
ax.scatter(X[indices, 0], X[indices, 1], color = '#bfbf00', label = "Line inliers")
ax.scatter(X[best_sample_points, 0], X[best_sample_points, 1], color = 'black', label = "Best sample for line")

x0, y0, r0 = best_fitted_circle
circle_gt = plt.Circle((x0, y0), r0, color='#c30fc3', fill=False, label='RANSAC circle')
ax.add_patch(circle_gt)
ax.plot(x0, y0, '+', color='black')

ax.scatter(X_rem[circ_inliers, 0], X_rem[circ_inliers, 1], color = '#00bfbf', label = "Circle inliers")
ax.scatter(X_rem[best_circ_sample_points, 0], X_rem[best_circ_sample_points, 1], color = 'red', label = "Best sample for circle")

plt.legend()

# %% [markdown]
# ## Question 3

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

def mouse_clicks(event, x, y, flags, params):
    global coordinates
    global count
    global first_image

    if event == cv.EVENT_LBUTTONDOWN:
        coordinates.append([x, y])
        count += 1

        first_image = cv.circle(first_image, (x,y), 2, (0, 0, 1), -1)
        cv.imshow("Image", first_image)

    if count == 4:
        cv.destroyAllWindows()
        cv.waitKey(1)

# Load images
im1 = cv.imread('005.jpg')
assert im1 is not None
im2 = cv.imread('flag.png')
assert im2 is not None

im1 = im1.astype(np.float64) / np.iinfo(im1.dtype).max

im2 = im2.astype(np.float64) / np.iinfo(im2.dtype).max

first_image = np.copy(im1)

coordinates = []
count = 0

cv.imshow("Image", im1)
cv.setMouseCallback("Image", mouse_clicks)
cv.waitKey(0)

cv.destroyAllWindows()

# Input parameters
X = np.array([[0, 0, 1],[im2.shape[1], 0, 1],[im2.shape[1], im2.shape[0], 1],[0, im2.shape[0], 1]]).T

Y = np.array([[coordinates[0][0], coordinates[0][1], 1],[coordinates[1][0], coordinates[1][1], 1],[coordinates[2][0], coordinates[2][1], 1],[coordinates[3][0], coordinates[3][1], 1],]).T

O = np.array([[0],[0],[0]])

A = []

for i in range(4):
    A.append(np.concatenate((O.T, np.expand_dims(X.T[i,:], axis=0), np.expand_dims(-1*Y[1, i]*X.T[i,:], axis=0) ), axis=1))
    A.append(np.concatenate((np.expand_dims(X.T[i,:], axis=0), O.T, np.expand_dims(-1*Y[0, i]*X.T[i,:], axis=0) ), axis=1))

A = np.array(A).squeeze().astype(np.float64)

eigen_values, eigen_vectors = np.linalg.eig(A.T @ A)
H = eigen_vectors[:, np.argmin(eigen_values)]
H = H.reshape(3, -1)

t_im2 = cv.warpPerspective(im2, H, (im1.shape[1], im1.shape[0]))

beta = 0.5
blended_img = cv.addWeighted(im1, 1, t_im2, beta, 0.0)
blended_img[blended_img > 1] = 1

first_image_rgb = cv.cvtColor(first_image.astype(np.float32), cv.COLOR_BGR2RGB)
im2_rgb = cv.cvtColor(im2.astype(np.float32), cv.COLOR_BGR2RGB)
blended_img_rgb = cv.cvtColor(blended_img.astype(np.float32), cv.COLOR_BGR2RGB)

fig, ax = plt.subplots(1, 3, figsize=(20, 10))
ax[0].imshow(first_image_rgb)
ax[1].imshow(im2_rgb)
ax[2].imshow(blended_img_rgb)

ax[0].set_title("Image 1")
ax[1].set_title("Image 2")
ax[2].set_title("Final Image")

ax[0].axis("off")
ax[1].axis("off")
ax[2].axis("off")

plt.show()

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

def mouse_clicks(event, x, y, flags, params):
    global coordinates
    global count
    global first_image

    if event == cv.EVENT_LBUTTONDOWN:
        coordinates.append([x, y])
        count += 1

        first_image = cv.circle(first_image, (x,y), 2, (0, 0, 1), -1)
        cv.imshow("Image", first_image)        
    
    if count == 4:
        cv.destroyAllWindows()
        cv.waitKey(1)

im1 = cv.imread('ground.jpg')
assert im1 is not None
im2 = cv.imread('olympic_logo.png')
assert im2 is not None

im1 = im1.astype(np.float64) / np.iinfo(im1.dtype).max

im2 = im2.astype(np.float64) / np.iinfo(im2.dtype).max

first_image = np.copy(im1)

coordinates = []
count = 0

cv.imshow("Image", im1)
cv.setMouseCallback("Image", mouse_clicks)
cv.waitKey(0)

cv.destroyAllWindows()

# Input parameters
X = np.array([[0, 0, 1],[im2.shape[1], 0, 1],[im2.shape[1], im2.shape[0], 1],[0, im2.shape[0], 1]]).T

Y = np.array([[coordinates[0][0], coordinates[0][1], 1],[coordinates[1][0], coordinates[1][1], 1],[coordinates[2][0], coordinates[2][1], 1],[coordinates[3][0], coordinates[3][1], 1],]).T

O = np.array([[0],[0],[0]])

A = []

for i in range(4):
    A.append(np.concatenate((O.T, np.expand_dims(X.T[i,:], axis=0), np.expand_dims(-1*Y[1, i]*X.T[i,:], axis=0) ), axis=1))
    A.append(np.concatenate((np.expand_dims(X.T[i,:], axis=0), O.T, np.expand_dims(-1*Y[0, i]*X.T[i,:], axis=0) ), axis=1))

A = np.array(A).squeeze().astype(np.float64)

eigen_values, eigen_vectors = np.linalg.eig(A.T @ A)
H = eigen_vectors[:, np.argmin(eigen_values)]
H = H.reshape(3, -1)

t_im2 = cv.warpPerspective(im2, H, (im1.shape[1], im1.shape[0]))

beta = 0.5
blended_img = cv.addWeighted(im1, 1, t_im2, beta, 0.0)
blended_img[blended_img > 1] = 1

first_image_rgb = cv.cvtColor(first_image.astype(np.float32), cv.COLOR_BGR2RGB) 
im2_rgb = cv.cvtColor(im2.astype(np.float32), cv.COLOR_BGR2RGB)
blended_img_rgb = cv.cvtColor(blended_img.astype(np.float32), cv.COLOR_BGR2RGB)

fig, ax = plt.subplots(1, 3, figsize=(20, 10))
ax[0].imshow(first_image_rgb)
ax[1].imshow(im2_rgb)
ax[2].imshow(blended_img_rgb)

ax[0].set_title("Image 1")
ax[1].set_title("Image 2")
ax[2].set_title("Final Image")

ax[0].axis("off")
ax[1].axis("off")
ax[2].axis("off")

plt.show()

plt.imshow(blended_img_rgb)
plt.title("Final Image")
plt.axis("off")
plt.show()

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

def mouse_clicks(event, x, y, flags, params):
    global coordinates
    global count
    global first_image

    if event == cv.EVENT_LBUTTONDOWN:
        coordinates.append([x, y])
        count += 1

        first_image = cv.circle(first_image, (x,y), 2, (0, 0, 1), -1)
        cv.imshow("Image", first_image)        
    
    if count == 4:
        cv.destroyAllWindows()
        cv.waitKey(1)

im1 = cv.imread('projector_screen.jpg')
assert im1 is not None
im2 = cv.imread('abhina.jpg')
assert im2 is not None

im1 = im1.astype(np.float64) / np.iinfo(im1.dtype).max

im2 = im2.astype(np.float64) / np.iinfo(im2.dtype).max

first_image = np.copy(im1)

coordinates = []
count = 0

cv.imshow("Image", im1)
cv.setMouseCallback("Image", mouse_clicks)
cv.waitKey(0)

cv.destroyAllWindows()

# Input parameters
X = np.array([[0, 0, 1],[im2.shape[1], 0, 1],[im2.shape[1], im2.shape[0], 1],[0, im2.shape[0], 1]]).T

Y = np.array([[coordinates[0][0], coordinates[0][1], 1],[coordinates[1][0], coordinates[1][1], 1],[coordinates[2][0], coordinates[2][1], 1],[coordinates[3][0], coordinates[3][1], 1],]).T

O = np.array([[0],[0],[0]])

A = []

for i in range(4):
    A.append(np.concatenate((O.T, np.expand_dims(X.T[i,:], axis=0), np.expand_dims(-1*Y[1, i]*X.T[i,:], axis=0) ), axis=1))
    A.append(np.concatenate((np.expand_dims(X.T[i,:], axis=0), O.T, np.expand_dims(-1*Y[0, i]*X.T[i,:], axis=0) ), axis=1))

A = np.array(A).squeeze().astype(np.float64)

eigen_values, eigen_vectors = np.linalg.eig(A.T @ A)
H = eigen_vectors[:, np.argmin(eigen_values)]
H = H.reshape(3, -1)

t_im2 = cv.warpPerspective(im2, H, (im1.shape[1], im1.shape[0]))

beta = 0.5
blended_img = cv.addWeighted(im1, 1, t_im2, beta, 0.0)
blended_img[blended_img > 1] = 1

first_image_rgb = cv.cvtColor(first_image.astype(np.float32), cv.COLOR_BGR2RGB) 
im2_rgb = cv.cvtColor(im2.astype(np.float32), cv.COLOR_BGR2RGB)
blended_img_rgb = cv.cvtColor(blended_img.astype(np.float32), cv.COLOR_BGR2RGB)

fig, ax = plt.subplots(1, 3, figsize=(20, 10))
ax[0].imshow(first_image_rgb)
ax[1].imshow(im2_rgb)
ax[2].imshow(blended_img_rgb)

ax[0].set_title("Image 1")
ax[1].set_title("Image 2")
ax[2].set_title("Final Image")

ax[0].axis("off")
ax[1].axis("off")
ax[2].axis("off")

plt.show()

plt.imshow(blended_img_rgb)
plt.title("Final Image")
plt.axis("off")
plt.show()
